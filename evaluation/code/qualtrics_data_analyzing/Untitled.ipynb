# %%
import qualtrics_data_processing

# %%
run qualtrics_data_processing.py
# Out:
# C:\Users\YangSong\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      58     df = pandas.read_excel('../BURT ICSE’22 Evaluation Survey_seven_users.xlsx', engine="openpyxl")
#      59
# ---> 60     screen_suggestion_usefulness = df['Q228'].values[1: len(df['Q228'].values)]
#      61     screen_suggestion_usefulness_list = []
#      62     for screen in screen_suggestion_usefulness:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'

# %%
run qualtrics_data_processing.py
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      59     # print the column names
#      60     # print(df.columns)
# ---> 61     screen_suggestion_usefulness = df['Q228'].values[1: len(df['Q228'].values)]
#      62     print(screen_suggestion_usefulness)
#      63     screen_suggestion_usefulness_list = []
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'

# %%
run qualtrics_data_processing.py
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      59     # print the column names
#      60     # print(df.columns)
# ---> 61     screen_suggestion_usefulness = df["Q228"].values[1: len(df["Q228"].values)]
#      62     print(screen_suggestion_usefulness)
#      63     screen_suggestion_usefulness_list = []
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'

# %%
run qualtrics_data_processing.py
# Out:
# Index(['StartDate'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      58     df = pandas.read_excel('../BURT ICSE’22 Evaluation Survey_seven_users.xlsx', engine="openpyxl")
#      59     print(df.columns)
# ---> 60     screen_suggestion_usefulness = df['Q228'].values[1: len(df['Q228'].values)]
#      61     print(screen_suggestion_usefulness)
#      62     screen_suggestion_usefulness_list = []
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'

# %%
run qualtrics_data_processing.py
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      58     df = pandas.read_excel('../BURT ICSE’22 Evaluation Survey_seven_users.xlsx', engine="openpyxl")
#      59
# ---> 60     screen_suggestion_usefulness = df['Q228'].values[1: len(df['Q228'].values)]
#      61     screen_suggestion_usefulness_list = []
#      62     for screen in screen_suggestion_usefulness:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Q228'

# %%
run qualtrics_data_processing.py
# Out:
# ['Sometimes', 'Sometimes', 'Sometimes', 'Often', 'Often', 'Often', 'Sometimes']
# Displaying chart at http://localhost:20302/

# %%
run qualtrics_data_processing.py
# Out:
# ['Sometimes', 'Sometimes', 'Sometimes', 'Often', 'Often', 'Often', 'Sometimes']
# screen_suggestion_usefulness
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.2857142857142857}]
# ['Sometimes', 'Sometimes', 'Always', 'Sometimes', 'Always', 'Often', 'Always']
# OB_understanding
# [{'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.21428571428571427}]
# ['Sometimes', 'Often', 'Always', 'Sometimes', 'Always', 'Always', 'Always']
# EB_understanding
# [{'question': 'EB_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Rarely', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.14285714285714285}]
# ['Sometimes', 'Sometimes', 'Often', 'Often', 'Often', 'Often', 'Rarely']
# S2R_understanding
# [{'question': 'S2R_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Rarely', 'percentage_start': 0.0, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.14285714285714285}]
# ['Sometimes', 'Sometimes', 'Often', 'Often', 'Often', 'Often', 'Rarely']
# BURT_messages_understanding
# [{'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'percentage_start': 0.0, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.14285714285714285}]
# Displaying chart at http://localhost:20302/

# %%
run qualtrics_data_processing.py
# Out:
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# Often
# {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}
# Always
# {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}
# {'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# Often
# {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}
# Always
# {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# Often
# {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}
# Always
# {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'EB_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}
# {'question': 'EB_understanding', 'type': 'Rarely', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}
# {'question': 'EB_understanding', 'type': 'Never', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}
# Often
# {'question': 'EB_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}
# Always
# {'question': 'EB_understanding', 'type': 'Always', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'S2R_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}
# {'question': 'S2R_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}
# {'question': 'S2R_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# Often
# {'question': 'S2R_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}
# Always
# {'question': 'S2R_understanding', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}
# {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}
# {'question': 'BURT_messages_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# Often
# {'question': 'BURT_messages_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}
# Always
# {'question': 'BURT_messages_understanding', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# Often
# Always
# Often
# Always
# Often
# Always
# Often
# Always
# Often
# Always
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'EB_understanding', 'type': 'Rarely', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}]
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}
# {'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# Often
# {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}
# Always
# {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# Often
# {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}
# Always
# {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'EB_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}
# {'question': 'EB_understanding', 'type': 'Rarely', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}
# {'question': 'EB_understanding', 'type': 'Never', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}
# Often
# {'question': 'EB_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}
# Always
# {'question': 'EB_understanding', 'type': 'Always', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'S2R_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}
# {'question': 'S2R_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}
# {'question': 'S2R_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# Often
# {'question': 'S2R_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}
# Always
# {'question': 'S2R_understanding', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}
# {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}
# {'question': 'BURT_messages_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}
# Often
# {'question': 'BURT_messages_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}
# Always
# {'question': 'BURT_messages_understanding', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      96                              'Somewhat difficult to use', 'Difficult to use']
#      97
# ---> 98     source_data = generate_chart_frequency([{"screen_suggestion_usefulness": screen_suggestion_usefulness_list},
#      99                               {"OB_understanding": OB_understanding_list},
#     100                               {"EB_understanding": EB_understanding_list},
#
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in generate_chart_frequency(question_list, likert_scale_frequency)
#      55 def generate_chart_frequency(question_list, likert_scale_frequency):
#      56     source_data_list = []
# ---> 57     for question in question_list[1,2]:
#      58         source_data_list.extend(generate_json_for_each_question(question, likert_scale_frequency))
#      59     return source_data_list
#
# TypeError: list indices must be integers or slices, not tuple

# %%
run qualtrics_data_processing.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      96                              'Somewhat difficult to use', 'Difficult to use']
#      97
# ---> 98     source_data = generate_chart_frequency([{"screen_suggestion_usefulness": screen_suggestion_usefulness_list},
#      99                               {"OB_understanding": OB_understanding_list},
#     100                               {"EB_understanding": EB_understanding_list},
#
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in generate_chart_frequency(question_list, likert_scale_frequency)
#      55 def generate_chart_frequency(question_list, likert_scale_frequency):
#      56     source_data_list = []
# ---> 57     for question in question_list[1,2]:
#      58         source_data_list.extend(generate_json_for_each_question(question, likert_scale_frequency))
#      59     return source_data_list
#
# TypeError: list indices must be integers or slices, not tuple

# %%
run qualtrics_data_processing.py
# Out:
# ['Always', 'Often', 'Sometimes', 'Rarely', 'Never']
# {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}
# Often
# {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}
# Always
# {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# Displaying chart at http://localhost:17351/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# Displaying chart at http://localhost:16660/

# %%
run qualtrics_data_processing.py
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#      98                              'Somewhat difficult to use', 'Difficult to use']
#      99
# --> 100     source_data = generate_chart_frequency([{"screen_suggestion_usefulness": screen_suggestion_usefulness_list},
#     101                                             {"OB_understanding": OB_understanding_list},
#     102                                             {"EB_understanding": EB_understanding_list},
#
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in generate_chart_frequency(question_list, likert_scale_frequency)
#      58     source_data_list = []
#      59     for question in question_list:
# ---> 60         source_data_list.extend(generate_json_for_each_question(question, likert_scale_frequency))
#      61     return source_data_list
#      62
#
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in generate_json_for_each_question(question_dict, likert_scale_frequency)
#      19     count = answer_list.count(likert_scale_frequency[2])
#      20     result_sometimes["value"] = count
# ---> 21     result["percentage"] = percentage
#      22     percentage_sometimes = count / total_number_of_answer
#      23     result_sometimes["percentage_start"] = -percentage_sometimes / 2
#
# UnboundLocalError: local variable 'percentage' referenced before assignment

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# Displaying chart at http://localhost:16660/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     125     )
#     126
# --> 127     alt.Chart(source).mark_bar().encode(
#     128         # x='percentage_start:Q',
#     129         # x2='percentage_end:Q',
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      55         self._kwds.update({k: v for k, v in parsed.items()
#      56                            if self._get(k) is Undefined})
# ---> 57         return super(FieldChannelMixin, self).to_dict(
#      58             validate=validate,
#      59             ignore=ignore,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.channels.X, validating 'required'
#
#         'type' is a required property

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     125     )
#     126
# --> 127     alt.Chart(source).mark_bar().encode(
#     128         # x='percentage_start:Q',
#     129         # x2='percentage_end:Q',
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      55         self._kwds.update({k: v for k, v in parsed.items()
#      56                            if self._get(k) is Undefined})
# ---> 57         return super(FieldChannelMixin, self).to_dict(
#      58             validate=validate,
#      59             ignore=ignore,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.channels.X, validating 'required'
#
#         'type' is a required property

# %%
run qualtrics_data_processing.py
# Out:
#   File "D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py", line 135
#     ).show()
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     125     )
#     126
# --> 127     alt.Chart(source).mark_bar().encode(
#     128         x=alt.X('percentage_start:Q','percentage_end:Q', scale=alt.Scale(domain=[-30, 100])),
#     129         y=alt.Y('question:N', axis=y_axis),
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      55         self._kwds.update({k: v for k, v in parsed.items()
#      56                            if self._get(k) is Undefined})
# ---> 57         return super(FieldChannelMixin, self).to_dict(
#      58             validate=validate,
#      59             ignore=ignore,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.channels.X->0, validating 'enum'
#
#         'percentage_end:Q' is not one of ['average', 'count', 'distinct', 'max', 'mean', 'median', 'min', 'missing', 'product', 'q1', 'q3', 'ci0', 'ci1', 'stderr', 'stdev', 'stdevp', 'sum', 'valid', 'values', 'variance', 'variancep']

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# Displaying chart at http://localhost:16660/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': -0.2857142857142857, 'percentage_end': 0.2857142857142857}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.7142857142857142}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'OB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.21428571428571427, 'percentage_end': -0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': -0.21428571428571427, 'percentage_end': 0.21428571428571427}, {'question': 'OB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.21428571428571427, 'percentage_end': 0.3571428571428571}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 0.42857142857142855, 'percentage_start': 0.3571428571428571, 'percentage_end': 0.7857142857142856}]
# [{'question': 'EB_understanding', 'type': 'Rarely', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.14285714285714285, 'percentage_end': -0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'EB_understanding', 'type': 'Often', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.2857142857142857}, {'question': 'EB_understanding', 'type': 'Always', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.2857142857142857, 'percentage_end': 0.8571428571428571}]
# [{'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'S2R_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# [{'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 0.14285714285714285, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Never', 'value': 0, 'percentage': 0.0, 'percentage_start': -0.2857142857142857, 'percentage_end': -0.2857142857142857}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 2, 'percentage': 0.2857142857142857, 'percentage_start': -0.14285714285714285, 'percentage_end': 0.14285714285714285}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 4, 'percentage': 0.5714285714285714, 'percentage_start': 0.14285714285714285, 'percentage_end': 0.7142857142857142}, {'question': 'BURT_messages_understanding', 'type': 'Always', 'value': 0, 'percentage': 0.0, 'percentage_start': 0.7142857142857142, 'percentage_end': 0.7142857142857142}]
# Displaying chart at http://localhost:16660/
