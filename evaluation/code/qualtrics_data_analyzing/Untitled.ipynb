# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'S2R_panel_usefulness', 'type': 'Useless', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_panel_usefulness', 'type': 'Neither useful nor useless', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 5.555555555555555, 'percentage_end': 11.11111111111111, 'position': 8.333333333333332, 'numbers': '5.6%'}, {'question': 'S2R_panel_usefulness', 'type': 'Somewhat useful', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 11.11111111111111, 'percentage_end': 38.888888888888886, 'position': 25.0, 'numbers': '27.8%'}, {'question': 'S2R_panel_usefulness', 'type': 'Useful', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:24548/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'BURT_easy_to_use', 'type': 'Somewhat difficult to use', 'value': 2, 'percentage': 11.11111111111111, 'percentage_start': 0, 'percentage_end': 11.11111111111111, 'position': 5.555555555555555, 'numbers': '11.1%'}, {'question': 'BURT_easy_to_use', 'type': 'Neither easy nor difficult to use', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 11.11111111111111, 'percentage_end': 38.888888888888886, 'position': 25.0, 'numbers': '27.8%'}, {'question': 'BURT_easy_to_use', 'type': 'Somewhat easy to use', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 38.888888888888886, 'percentage_end': 83.33333333333333, 'position': 61.11111111111111, 'numbers': '44.4%'}, {'question': 'BURT_easy_to_use', 'type': 'Easy to use', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333333, 'percentage_end': 100.0, 'position': 91.66666666666666, 'numbers': '16.7%'}]
# Displaying chart at http://localhost:24548/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:17069/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         orient='bottom'
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in layer(*charts, **kwargs)
#    2320 def layer(*charts, **kwargs):
#    2321     """layer multiple charts"""
# -> 2322     return LayerChart(layer=charts, **kwargs)
#    2323
#    2324
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in __init__(self, data, layer, **kwargs)
#    2257         # TODO: check for conflicting interaction
#    2258         for spec in layer:
# -> 2259             _check_if_valid_subspec(spec, "LayerChart")
#    2260             _check_if_can_be_layered(spec)
#    2261         super(LayerChart, self).__init__(data=data, layer=list(layer), **kwargs)
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in _check_if_valid_subspec(spec, classname)
#    2043             val = spec.get(attr, Undefined)
#    2044         if val is not Undefined:
# -> 2045             raise ValueError(err.format(attr, classname))
#    2046
#    2047
#
# ValueError: Objects with "config" attribute cannot be used within LayerChart. Consider defining the config attribute in the LayerChart object instead.

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         order=alt.Order('color_Response_sort_index:Q'),
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in layer(*charts, **kwargs)
#    2320 def layer(*charts, **kwargs):
#    2321     """layer multiple charts"""
# -> 2322     return LayerChart(layer=charts, **kwargs)
#    2323
#    2324
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in __init__(self, data, layer, **kwargs)
#    2257         # TODO: check for conflicting interaction
#    2258         for spec in layer:
# -> 2259             _check_if_valid_subspec(spec, "LayerChart")
#    2260             _check_if_can_be_layered(spec)
#    2261         super(LayerChart, self).__init__(data=data, layer=list(layer), **kwargs)
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in _check_if_valid_subspec(spec, classname)
#    2043             val = spec.get(attr, Undefined)
#    2044         if val is not Undefined:
# -> 2045             raise ValueError(err.format(attr, classname))
#    2046
#    2047
#
# ValueError: Objects with "config" attribute cannot be used within LayerChart. Consider defining the config attribute in the LayerChart object instead.

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion_usefulness', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion_usefulness', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB_understanding', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB_understanding', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB_understanding', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB_understanding', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB_understanding', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB_understanding', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'BURT_messages_understanding', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'BURT_messages_understanding', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'BURT_messages_understanding', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'messages', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'messages', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'messages', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     226         order=alt.Order('color_Response_sort_index:Q'),
#     227     )
# --> 228     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      38             elif not (type_in_shorthand or type_defined_explicitly):
#      39                 if isinstance(context.get('data', None), pd.DataFrame):
# ---> 40                     raise ValueError("{} encoding field is specified without a type; "
#      41                                      "the type cannot be inferred because it does not "
#      42                                      "match any column in the data.".format(shorthand))
#
# ValueError: numbers encoding field is specified without a type; the type cannot be inferred because it does not match any column in the data.

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'messages', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'messages', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'messages', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'screen_suggestion', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'screen_suggestion', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'screen_suggestion', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'messages', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'messages', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'messages', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen suggestion', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'Screen suggestion', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'Screen suggestion', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'Messages', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'Messages', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'Messages', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': '1.screen suggestion', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': '1.screen suggestion', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': '1.screen suggestion', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': '2.OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': '2.OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': '2.OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': '3.EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': '3.EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': '3.EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': '3.EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': '4.S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': '4.S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': '4.S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': '5.Messages', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': '5.Messages', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': '5.Messages', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'Messages', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'Messages', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'Messages', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%'}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%'}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%'}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%'}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%'}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%'}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%'}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%'}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%'}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%'}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%'}]
# C:\Users\YangSong\anaconda3\lib\site-packages\altair\utils\core.py:673: UserWarning: Unrecognized encoding channel 'sort'
#   warnings.warn("Unrecognized encoding channel '{}'".format(encoding))
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     228         order=alt.Order('color_Response_sort_index:Q'),
#     229     )
# --> 230     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.FacetedEncoding, validating 'additionalProperties'
#
#         Additional properties are not allowed ('sort' was unexpected)

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         order=alt.Order('color_Response_sort_index:Q'),
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.FacetedEncoding, validating 'additionalProperties'
#
#         Additional properties are not allowed ('sort' was unexpected)

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         order=alt.Order('color_Response_sort_index:Q'),
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.FacetedEncoding, validating 'additionalProperties'
#
#         Additional properties are not allowed ('sort' was unexpected)

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         order=alt.Order('color_Response_sort_index:Q'),
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      55         self._kwds.update({k: v for k, v in parsed.items()
#      56                            if self._get(k) is Undefined})
# ---> 57         return super(FieldChannelMixin, self).to_dict(
#      58             validate=validate,
#      59             ignore=ignore,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.channels.Y->0, validating 'type'
#
#         'index' is not of type 'array'

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         order=alt.Order('color_Response_sort_index:Q'),
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\channels.py in to_dict(self, validate, ignore, context)
#      55         self._kwds.update({k: v for k, v in parsed.items()
#      56                            if self._get(k) is Undefined})
# ---> 57         return super(FieldChannelMixin, self).to_dict(
#      58             validate=validate,
#      59             ignore=ignore,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.channels.Y->0, validating 'type'
#
#         'index:Q' is not of type 'array'

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     229         order=alt.Order('color_Response_sort_index:Q'),
#     230     )
# --> 231     alt.layer(bars, text).show()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in show(self, embed_opt, open_browser)
#    1768                 "See http://github.com/altair-viz/altair_viewer"
#    1769             )
# -> 1770         altair_viewer.show(self, embed_opt=embed_opt, open_browser=open_browser)
#    1771
#    1772     @utils.use_signature(core.Resolve)
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in show(self, chart, embed_opt, open_browser)
#     353         render : Jupyter renderer for chart.
#     354         """
# --> 355         msg = self.display(chart, embed_opt=embed_opt, open_browser=open_browser)
#     356         print(msg)
#     357         if self._provider is not None:
#
# ~\anaconda3\lib\site-packages\altair_viewer\_viewer.py in display(self, chart, inline, embed_opt, open_browser)
#     262         """
#     263         if isinstance(chart, alt.TopLevelMixin):
# --> 264             chart = chart.to_dict()
#     265         assert isinstance(chart, dict)
#     266         self._initialize()
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <listcomp>(.0)
#      56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
# ---> 58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
#      60         return {
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     380         if dct is None:
#     381             kwargs["validate"] = "deep"
# --> 382             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     383
#     384         # TODO: following entries are added after validation. Should they be validated?
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      58         return [_todict(v, validate, context) for v in obj]
#      59     elif isinstance(obj, dict):
# ---> 60         return {
#      61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in <dictcomp>(.0)
#      59     elif isinstance(obj, dict):
#      60         return {
# ---> 61             k: _todict(v, validate, context)
#      62             for k, v in obj.items()
#      63             if v is not Undefined
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
#      54     """Convert an object to a dict representation."""
#      55     if isinstance(obj, SchemaBase):
# ---> 56         return obj.to_dict(validate=validate, context=context)
#      57     elif isinstance(obj, (list, tuple, np.ndarray)):
#      58         return [_todict(v, validate, context) for v in obj]
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.FacetedEncoding, validating 'additionalProperties'
#
#         Additional properties are not allowed ('sort' was unexpected)

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     206         x2=alt.X2('percentage_end:Q'),
#     207         # x=alt.X('sum(value):Q', stack='zero'),
# --> 208         y=alt.Y('question:N', sort=alt.SortField(field="index", op="sum", order='ascending')),
#     209         color=alt.Color(
#     210             'type:N',
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\core.py in __init__(self, field, order, **kwds)
#   14793
#   14794     def __init__(self, field=Undefined, order=Undefined, **kwds):
# > 14795         super(SortField, self).__init__(field=field, order=order, **kwds)
#   14796
#   14797
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in __init__(self, *args, **kwds)
#     174
#     175         if DEBUG_MODE and self._class_is_valid_at_instantiation:
# --> 176             self.to_dict(validate=True)
#     177
#     178     def copy(self, deep=True, ignore=()):
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.SortField, validating 'additionalProperties'
#
#         Additional properties are not allowed ('op' was unexpected)

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     206         x2=alt.X2('percentage_end:Q'),
#     207         # x=alt.X('sum(value):Q', stack='zero'),
# --> 208         y=alt.Y('question:N', sort=alt.SortField(field="index", op='sum', order='ascending')),
#     209         color=alt.Color(
#     210             'type:N',
#
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\schema\core.py in __init__(self, field, order, **kwds)
#   14793
#   14794     def __init__(self, field=Undefined, order=Undefined, **kwds):
# > 14795         super(SortField, self).__init__(field=field, order=order, **kwds)
#   14796
#   14797
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in __init__(self, *args, **kwds)
#     174
#     175         if DEBUG_MODE and self._class_is_valid_at_instantiation:
# --> 176             self.to_dict(validate=True)
#     177
#     178     def copy(self, deep=True, ignore=()):
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.SortField, validating 'additionalProperties'
#
#         Additional properties are not allowed ('op' was unexpected)

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'WB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'WB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'WB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'WB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# D:\Projects\burt\evaluation\code\qualtrics_data_analyzing\qualtrics_data_processing.py in <module>
#     206         x2=alt.X2('percentage_end:Q'),
#     207         # x=alt.X('sum(value):Q', stack='zero'),
# --> 208         y=alt.Y('question:N', sort=-x),
#     209         color=alt.Color(
#     210             'type:N',
#
# NameError: name 'x' is not defined

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:18363/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:15659/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:15659/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': 'Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': 'Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': 'Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': 'AB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': 'AB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': 'AB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': 'EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': 'EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': 'EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': 'EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': 'S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': 'S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': 'S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': 'Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': 'Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': 'Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:15659/

# %%
run qualtrics_data_processing.py
# Out:
# [{'question': '1.Screen', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 0}, {'question': '1.Screen', 'type': 'Often', 'value': 9, 'percentage': 50.0, 'percentage_start': 44.44444444444444, 'percentage_end': 94.44444444444444, 'position': 69.44444444444444, 'numbers': '50.0%', 'index': 0}, {'question': '1.Screen', 'type': 'Always', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 94.44444444444444, 'percentage_end': 100.0, 'position': 97.22222222222221, 'numbers': '5.6%', 'index': 0}, {'question': '2.OB', 'type': 'Sometimes', 'value': 8, 'percentage': 44.44444444444444, 'percentage_start': 0, 'percentage_end': 44.44444444444444, 'position': 22.22222222222222, 'numbers': '44.4%', 'index': 1}, {'question': '2.OB', 'type': 'Often', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 44.44444444444444, 'percentage_end': 83.33333333333334, 'position': 63.888888888888886, 'numbers': '38.9%', 'index': 1}, {'question': '2.OB', 'type': 'Always', 'value': 3, 'percentage': 16.666666666666664, 'percentage_start': 83.33333333333334, 'percentage_end': 100.0, 'position': 91.66666666666667, 'numbers': '16.7%', 'index': 1}, {'question': '3.EB', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 2}, {'question': '3.EB', 'type': 'Sometimes', 'value': 7, 'percentage': 38.88888888888889, 'percentage_start': 5.555555555555555, 'percentage_end': 44.44444444444445, 'position': 25.0, 'numbers': '38.9%', 'index': 2}, {'question': '3.EB', 'type': 'Often', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 44.44444444444445, 'percentage_end': 72.22222222222223, 'position': 58.33333333333334, 'numbers': '27.8%', 'index': 2}, {'question': '3.EB', 'type': 'Always', 'value': 5, 'percentage': 27.77777777777778, 'percentage_start': 72.22222222222223, 'percentage_end': 100.0, 'position': 86.11111111111111, 'numbers': '27.8%', 'index': 2}, {'question': '4.S2R', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 3}, {'question': '4.S2R', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 3}, {'question': '4.S2R', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 3}, {'question': '5.Message', 'type': 'Rarely', 'value': 1, 'percentage': 5.555555555555555, 'percentage_start': 0, 'percentage_end': 5.555555555555555, 'position': 2.7777777777777777, 'numbers': '5.6%', 'index': 4}, {'question': '5.Message', 'type': 'Sometimes', 'value': 6, 'percentage': 33.33333333333333, 'percentage_start': 5.555555555555555, 'percentage_end': 38.888888888888886, 'position': 22.22222222222222, 'numbers': '33.3%', 'index': 4}, {'question': '5.Message', 'type': 'Often', 'value': 11, 'percentage': 61.111111111111114, 'percentage_start': 38.888888888888886, 'percentage_end': 100.0, 'position': 69.44444444444444, 'numbers': '61.1%', 'index': 4}]
# Displaying chart at http://localhost:15659/
